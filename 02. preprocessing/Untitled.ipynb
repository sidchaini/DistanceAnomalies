# %%
import pandas as pd

# %%
df_stars = pd.read_csv("stardata_share.csv",index_col=0)

# %%
df_bd = pd.read_csv("BDdata_share.csv",index_col=0)

# %%
df_stars = df_stars.loc[:,df_stars.columns[-15:]]

df_bd = df_bd.loc[:,df_bd.columns[-15:]]

assert (df_bd.columns == df_stars.columns).all()

# %%
import missingno as msno

# %%
df_stars["class"] = "star"
df_bd["class"] = "browndwarf"

# %%
df = pd.concat([df_stars,df_bd])

# %%
msno.matrix(df_bd.drop("class",axis=1))
# Out:
# <Axes: >

# %%
df_stars.loc[(df_stars["y-H"].isna())]
# Out:
# Empty DataFrame
# Columns: [z-y, z-Y, z-J, z-H, z-K, y-Y, y-J, y-H, y-K, Y-J, Y-H, Y-K, J-H, J-K, H-K, class]
# Index: []

# %%
import seaborn as sns

# %%
import numpy as np

# %%
df.columns.shape
# Out:
# (16,)

# %%
np.unique(df.columns).shape
# Out:
# (16,)

# %%
sns.pairplot(df_bd,hue="class")

# %%
sns.pairplot(pd.concat([df_bd,df_stars.sample(n=300)]),hue="class")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 sns.pairplot(pd.concat([df_bd,df_stars.sample(n=300)]),hue="class")
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:2153, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2151     diag_kws.setdefault("fill", True)
#    2152     diag_kws.setdefault("warn_singular", False)
# -> 2153     grid.map_diag(kdeplot, **diag_kws)
#    2155 # Maybe plot on the off-diagonals
#    2156 if diag_kind is not None:
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:1513, in PairGrid.map_diag(self, func, **kwargs)
#    1511     plot_kwargs.setdefault("hue_order", self._hue_order)
#    1512     plot_kwargs.setdefault("palette", self._orig_palette)
# ...
